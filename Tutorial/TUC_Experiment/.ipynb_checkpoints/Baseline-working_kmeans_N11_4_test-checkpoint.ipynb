# %%
clustering_result=['0', '1234', '5', '6']

# %%
import os, sys

path_name = os.path.dirname(os.path.abspath(os.path.dirname(os.getcwd())))
sys.path.append(path_name)

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from fbprophet import Prophet
from Engine.Data.IO import IO
from Engine.Pipeline.pipeline import NextoptBasePipeline,NextoptWeekdayDMPipeline,NextoptWeekdayDMProphetPipeline
from Engine.Data.IO import IO
from Engine.Data.transformer import Transformer
from Engine.Data.explorer import Explorer

# 1. Input
path_name = os.path.dirname(os.path.abspath(os.path.dirname(os.getcwd())))
sys.path.append(path_name)
print(path_name)

data_dir = path_name + '/Data/DB'

df_pallets = IO.read_pickle(data_dir + '/KPP일별_발주_유형별전처리.pkl') 
# 2. Transformer
df_pallets.head()
df_pallets.transformer.dt_format = '%Y%m%d' 

df_N11 = df_pallets.transformer.get(code=['N11'], weekday=[0,1,2,3,4,5,6],start='2012-01-01', end='2017-12-31').fillna(0.0)
df_L14 = df_pallets.transformer.get(code=['L14'], weekday=[0,1,2,3,4,5,6],start='2012-01-01', end='2017-12-31').fillna(0.0)
df_P11 = df_pallets.transformer.get(code=['P11'], weekday=[0,1,2,3,4,5,6],start='2012-01-01', end='2017-12-31').fillna(0.0)
df_P13= df_pallets.transformer.get(code=['P13'], weekday=[0,1,2,3,4,5,6],start='2012-01-01', end='2017-12-31').fillna(0.0)
df_P14= df_pallets.transformer.get(code=['P14'], weekday=[0,1,2,3,4,5,6],start='2012-01-01', end='2017-12-31').fillna(0.0)
df_set=[df_N11,df_L14,df_P11,df_P13,df_P14]
# Out:
# /Users/moonygo/Documents/NextoptEngine_light

# %%
df = df_pallets.transformer.get(code=['N11'], weekday=[0,1,2,3,4,5,6],start='2012-01-01', end='2017-12-31')
df = df.fillna(0)
df = df.reset_index()
df.columns = ['ds','y']

pipeline = NextoptWeekdayDMProphetPipeline()
pipeline.raw_data = df
pipeline.horizon = 30 # 예측할 기간(defualt: 30)
pipeline.unit = 'd'

df_holiday_main = IO.read_pickle('../../Data/기타/holiday/1. 설날과추석.pkl')
df_holiday_sub = IO.read_pickle('../../Data/기타/holiday/2. 일반공휴일.pkl')
df_holiday_main['lower_window'] = 0
df_holiday_main['upper_window'] = 0
df_holiday_main['holiday'] = '중요휴일'

df_holiday_sub['lower_window'] = 0
df_holiday_sub['upper_window'] = 0
df_holiday_sub['holiday'] = '보통휴일'

df_holidays = pd.concat([df_holiday_main, df_holiday_sub])

pipeline.cross_validation_split(fold = 12)

#pipeline.division_condition = ['0','1','2','3','4','5','6'] # mon - thur, sat, sun
#pipeline.division_condition=['01234','5','6']
#pipeline.division_condition=['012345','6']
pipeline.division_condition = clustering_result
pipeline.division_condition

pipeline.model = Prophet(
        daily_seasonality= False,
        weekly_seasonality= True,
        yearly_seasonality= True,
        holidays = df_holidays
)
pipeline.fit_and_predict()
pipeline.merge_forecast()

pipeline.postprocess(holiday_correction_dict={0: df_holiday_main,
                                          0: df_holiday_sub
                                         })
pipeline.evaluate()
pipeline.print_summary()
pipeline.plot_forecast()
# Out:
# SET INDEX AS DS(DateTimeIndex)
# CROSS VALIDATION SPLIT IS DONE.
# DIVIDE TRAIN BY WEEKDAY
# DIVIDE EACH FOLD BY WEEKDAY
# FOLD  1  DIVISION  1  RESET TRAIN, TEST INDEX FOR PROPHET MODEL
# FOLD  1  DIVISION  2  RESET TRAIN, TEST INDEX FOR PROPHET MODEL
# /anaconda3/envs/nextopt/lib/python3.6/site-packages/pystan/misc.py:399: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   elif np.issubdtype(np.asarray(v).dtype, float):
# FOLD  1  DIVISION  3  RESET TRAIN, TEST INDEX FOR PROPHET MODEL
# FOLD  1  DIVISION  4  RESET TRAIN, TEST INDEX FOR PROPHET MODEL
# FOLD  2  DIVISION  1  RESET TRAIN, TEST INDEX FOR PROPHET MODEL
# FOLD  2  DIVISION  2  RESET TRAIN, TEST INDEX FOR PROPHET MODEL
# FOLD  2  DIVISION  3  RESET TRAIN, TEST INDEX FOR PROPHET MODEL
# FOLD  2  DIVISION  4  RESET TRAIN, TEST INDEX FOR PROPHET MODEL
# FOLD  3  DIVISION  1  RESET TRAIN, TEST INDEX FOR PROPHET MODEL
# FOLD  3  DIVISION  2  RESET TRAIN, TEST INDEX FOR PROPHET MODEL
# FOLD  3  DIVISION  3  RESET TRAIN, TEST INDEX FOR PROPHET MODEL
# FOLD  3  DIVISION  4  RESET TRAIN, TEST INDEX FOR PROPHET MODEL
# FOLD  4  DIVISION  1  RESET TRAIN, TEST INDEX FOR PROPHET MODEL
# FOLD  4  DIVISION  2  RESET TRAIN, TEST INDEX FOR PROPHET MODEL
# FOLD  4  DIVISION  3  RESET TRAIN, TEST INDEX FOR PROPHET MODEL
# FOLD  4  DIVISION  4  RESET TRAIN, TEST INDEX FOR PROPHET MODEL
# FOLD  5  DIVISION  1  RESET TRAIN, TEST INDEX FOR PROPHET MODEL
# FOLD  5  DIVISION  2  RESET TRAIN, TEST INDEX FOR PROPHET MODEL
# FOLD  5  DIVISION  3  RESET TRAIN, TEST INDEX FOR PROPHET MODEL
# FOLD  5  DIVISION  4  RESET TRAIN, TEST INDEX FOR PROPHET MODEL
# FOLD  6  DIVISION  1  RESET TRAIN, TEST INDEX FOR PROPHET MODEL
# FOLD  6  DIVISION  2  RESET TRAIN, TEST INDEX FOR PROPHET MODEL
# FOLD  6  DIVISION  3  RESET TRAIN, TEST INDEX FOR PROPHET MODEL
# FOLD  6  DIVISION  4  RESET TRAIN, TEST INDEX FOR PROPHET MODEL
# FOLD  7  DIVISION  1  RESET TRAIN, TEST INDEX FOR PROPHET MODEL
# FOLD  7  DIVISION  2  RESET TRAIN, TEST INDEX FOR PROPHET MODEL
# FOLD  7  DIVISION  3  RESET TRAIN, TEST INDEX FOR PROPHET MODEL
# FOLD  7  DIVISION  4  RESET TRAIN, TEST INDEX FOR PROPHET MODEL
# FOLD  8  DIVISION  1  RESET TRAIN, TEST INDEX FOR PROPHET MODEL
# FOLD  8  DIVISION  2  RESET TRAIN, TEST INDEX FOR PROPHET MODEL
# FOLD  8  DIVISION  3  RESET TRAIN, TEST INDEX FOR PROPHET MODEL
# FOLD  8  DIVISION  4  RESET TRAIN, TEST INDEX FOR PROPHET MODEL
# FOLD  9  DIVISION  1  RESET TRAIN, TEST INDEX FOR PROPHET MODEL
# FOLD  9  DIVISION  2  RESET TRAIN, TEST INDEX FOR PROPHET MODEL
# FOLD  9  DIVISION  3  RESET TRAIN, TEST INDEX FOR PROPHET MODEL
# FOLD  9  DIVISION  4  RESET TRAIN, TEST INDEX FOR PROPHET MODEL
# FOLD  10  DIVISION  1  RESET TRAIN, TEST INDEX FOR PROPHET MODEL
# FOLD  10  DIVISION  2  RESET TRAIN, TEST INDEX FOR PROPHET MODEL
# FOLD  10  DIVISION  3  RESET TRAIN, TEST INDEX FOR PROPHET MODEL
# FOLD  10  DIVISION  4  RESET TRAIN, TEST INDEX FOR PROPHET MODEL
# FOLD  11  DIVISION  1  RESET TRAIN, TEST INDEX FOR PROPHET MODEL
# FOLD  11  DIVISION  2  RESET TRAIN, TEST INDEX FOR PROPHET MODEL
# FOLD  11  DIVISION  3  RESET TRAIN, TEST INDEX FOR PROPHET MODEL
# FOLD  11  DIVISION  4  RESET TRAIN, TEST INDEX FOR PROPHET MODEL
# FOLD  12  DIVISION  1  RESET TRAIN, TEST INDEX FOR PROPHET MODEL
# FOLD  12  DIVISION  2  RESET TRAIN, TEST INDEX FOR PROPHET MODEL
# FOLD  12  DIVISION  3  RESET TRAIN, TEST INDEX FOR PROPHET MODEL
# FOLD  12  DIVISION  4  RESET TRAIN, TEST INDEX FOR PROPHET MODEL
# FOLD  1  DIVISION  1  FIT AND FORECAST DONE
# FOLD  1  DIVISION  2  FIT AND FORECAST DONE
# FOLD  1  DIVISION  3  FIT AND FORECAST DONE
# FOLD  1  DIVISION  4  FIT AND FORECAST DONE
# FOLD  2  DIVISION  1  FIT AND FORECAST DONE
# FOLD  2  DIVISION  2  FIT AND FORECAST DONE
# FOLD  2  DIVISION  3  FIT AND FORECAST DONE
# FOLD  2  DIVISION  4  FIT AND FORECAST DONE
# FOLD  3  DIVISION  1  FIT AND FORECAST DONE
# FOLD  3  DIVISION  2  FIT AND FORECAST DONE
# FOLD  3  DIVISION  3  FIT AND FORECAST DONE
# FOLD  3  DIVISION  4  FIT AND FORECAST DONE
# FOLD  4  DIVISION  1  FIT AND FORECAST DONE
# FOLD  4  DIVISION  2  FIT AND FORECAST DONE
# FOLD  4  DIVISION  3  FIT AND FORECAST DONE
# FOLD  4  DIVISION  4  FIT AND FORECAST DONE
# FOLD  5  DIVISION  1  FIT AND FORECAST DONE
# FOLD  5  DIVISION  2  FIT AND FORECAST DONE
# FOLD  5  DIVISION  3  FIT AND FORECAST DONE
# FOLD  5  DIVISION  4  FIT AND FORECAST DONE
# FOLD  6  DIVISION  1  FIT AND FORECAST DONE
# FOLD  6  DIVISION  2  FIT AND FORECAST DONE
# FOLD  6  DIVISION  3  FIT AND FORECAST DONE
# FOLD  6  DIVISION  4  FIT AND FORECAST DONE
# FOLD  7  DIVISION  1  FIT AND FORECAST DONE
# FOLD  7  DIVISION  2  FIT AND FORECAST DONE
# FOLD  7  DIVISION  3  FIT AND FORECAST DONE
# FOLD  7  DIVISION  4  FIT AND FORECAST DONE
# FOLD  8  DIVISION  1  FIT AND FORECAST DONE
# FOLD  8  DIVISION  2  FIT AND FORECAST DONE
# FOLD  8  DIVISION  3  FIT AND FORECAST DONE
# FOLD  8  DIVISION  4  FIT AND FORECAST DONE
# FOLD  9  DIVISION  1  FIT AND FORECAST DONE
# FOLD  9  DIVISION  2  FIT AND FORECAST DONE
# FOLD  9  DIVISION  3  FIT AND FORECAST DONE
# FOLD  9  DIVISION  4  FIT AND FORECAST DONE
# FOLD  10  DIVISION  1  FIT AND FORECAST DONE
# FOLD  10  DIVISION  2  FIT AND FORECAST DONE
# FOLD  10  DIVISION  3  FIT AND FORECAST DONE
# FOLD  10  DIVISION  4  FIT AND FORECAST DONE
# FOLD  11  DIVISION  1  FIT AND FORECAST DONE
# FOLD  11  DIVISION  2  FIT AND FORECAST DONE
# FOLD  11  DIVISION  3  FIT AND FORECAST DONE
# FOLD  11  DIVISION  4  FIT AND FORECAST DONE
# FOLD  12  DIVISION  1  FIT AND FORECAST DONE
# FOLD  12  DIVISION  2  FIT AND FORECAST DONE
# FOLD  12  DIVISION  3  FIT AND FORECAST DONE
# FOLD  12  DIVISION  4  FIT AND FORECAST DONE
# MERGE DIVIDED FORECAST INTO FORECAST_TRAIN & FORECAST_TEST
# POSTPROCESS YHAT = 0 IF YHAT < 0
# POSTPROCESS Holiday
# POSTPROCESS YHAT = 0 IF YHAT < 0
# POSTPROCESS Holiday
# POSTPROCESS YHAT = 0 IF YHAT < 0
# POSTPROCESS Holiday
# POSTPROCESS YHAT = 0 IF YHAT < 0
# POSTPROCESS Holiday
# POSTPROCESS YHAT = 0 IF YHAT < 0
# POSTPROCESS Holiday
# POSTPROCESS YHAT = 0 IF YHAT < 0
# POSTPROCESS Holiday
# POSTPROCESS YHAT = 0 IF YHAT < 0
# POSTPROCESS Holiday
# POSTPROCESS YHAT = 0 IF YHAT < 0
# POSTPROCESS Holiday
# POSTPROCESS YHAT = 0 IF YHAT < 0
# POSTPROCESS Holiday
# POSTPROCESS YHAT = 0 IF YHAT < 0
# POSTPROCESS Holiday
# POSTPROCESS YHAT = 0 IF YHAT < 0
# POSTPROCESS Holiday
# POSTPROCESS YHAT = 0 IF YHAT < 0
# POSTPROCESS Holiday
# POSTPROCESS YHAT = 0 IF YHAT < 0
# POSTPROCESS Holiday
# POSTPROCESS YHAT = 0 IF YHAT < 0
# POSTPROCESS Holiday
# POSTPROCESS YHAT = 0 IF YHAT < 0
# POSTPROCESS Holiday
# POSTPROCESS YHAT = 0 IF YHAT < 0
# POSTPROCESS Holiday
# POSTPROCESS YHAT = 0 IF YHAT < 0
# POSTPROCESS Holiday
# POSTPROCESS YHAT = 0 IF YHAT < 0
# POSTPROCESS Holiday
# POSTPROCESS YHAT = 0 IF YHAT < 0
# POSTPROCESS Holiday
# POSTPROCESS YHAT = 0 IF YHAT < 0
# POSTPROCESS Holiday
# POSTPROCESS YHAT = 0 IF YHAT < 0
# POSTPROCESS Holiday
# POSTPROCESS YHAT = 0 IF YHAT < 0
# POSTPROCESS Holiday
# POSTPROCESS YHAT = 0 IF YHAT < 0
# POSTPROCESS Holiday
# POSTPROCESS YHAT = 0 IF YHAT < 0
# POSTPROCESS Holiday
#     Fold       From         To     Real     Predict     Error  Error(%)  \
# 12    12 2017-01-06 2017-02-04  1512068  1544629.03 -32561.03     -2.15
# 11    11 2017-02-05 2017-03-06  1557184  1477420.83  79763.17      5.12
# 10    10 2017-03-07 2017-04-05  1715286  1662511.17  52774.83      3.08
# 9      9 2017-04-06 2017-05-05  1599588  1553988.45  45599.55      2.85
# 8      8 2017-05-06 2017-06-04  1618014  1574676.99  43337.01      2.68
# 7      7 2017-06-05 2017-07-04  1718152  1720516.69  -2364.69     -0.14
# 6      6 2017-07-05 2017-08-03  1699665  1735876.81 -36211.81     -2.13
# 5      5 2017-08-04 2017-09-02  1703679  1746090.14 -42411.14     -2.49
# 4      4 2017-09-03 2017-10-02  1808586  1758607.64  49978.36      2.76
# 3      3 2017-10-03 2017-11-01  1570505  1509948.36  60556.64      3.86
# 2      2 2017-11-02 2017-12-01  1697172  1757080.61 -59908.61     -3.53
# 1      1 2017-12-02 2017-12-31  1438054  1490170.79 -52116.79     -3.62
#
#     Total Error  Total Error(%)      RMSE     MAPE  sMAPE
# 12    131476.37            8.70   5906.55  1985.47   8.60
# 11    125249.44            8.04   8437.40    14.24   8.25
# 10     92973.95            5.42   3839.60     7.10   5.51
# 9     156950.64            9.81  10444.70    19.65   9.95
# 8     132914.70            8.21  10594.37    16.84   8.33
# 7     140446.52            8.17   9298.69    13.60   8.17
# 6     112059.55            6.59   5394.79    10.63   6.52
# 5     164982.28            9.68   9523.04    13.48   9.56
# 4     145649.07            8.05   7179.29    19.49   8.17
# 3     178586.34           11.37  10182.55   122.64  11.59
# 2     109695.63            6.46   4677.23    19.39   6.35
# 1     107925.40            7.50   5064.74    18.68   7.37
# Fold  12 	 2017-01-06 00:00:00  -  2017-02-04 00:00:00
# Fold  11 	 2017-02-05 00:00:00  -  2017-03-06 00:00:00
# Fold  10 	 2017-03-07 00:00:00  -  2017-04-05 00:00:00
# Fold  9 	 2017-04-06 00:00:00  -  2017-05-05 00:00:00
# Fold  8 	 2017-05-06 00:00:00  -  2017-06-04 00:00:00
# Fold  7 	 2017-06-05 00:00:00  -  2017-07-04 00:00:00
# Fold  6 	 2017-07-05 00:00:00  -  2017-08-03 00:00:00
# Fold  5 	 2017-08-04 00:00:00  -  2017-09-02 00:00:00
# Fold  4 	 2017-09-03 00:00:00  -  2017-10-02 00:00:00
# Fold  3 	 2017-10-03 00:00:00  -  2017-11-01 00:00:00
# Fold  2 	 2017-11-02 00:00:00  -  2017-12-01 00:00:00
# Fold  1 	 2017-12-02 00:00:00  -  2017-12-31 00:00:00

# %%
pipeline.print_summary()
# Out:
#     Fold       From         To     Real     Predict     Error  Error(%)  \
# 12    12 2017-01-06 2017-02-04  1512068  1544629.03 -32561.03     -2.15
# 11    11 2017-02-05 2017-03-06  1557184  1477420.83  79763.17      5.12
# 10    10 2017-03-07 2017-04-05  1715286  1662511.17  52774.83      3.08
# 9      9 2017-04-06 2017-05-05  1599588  1553988.45  45599.55      2.85
# 8      8 2017-05-06 2017-06-04  1618014  1574676.99  43337.01      2.68
# 7      7 2017-06-05 2017-07-04  1718152  1720516.69  -2364.69     -0.14
# 6      6 2017-07-05 2017-08-03  1699665  1735876.81 -36211.81     -2.13
# 5      5 2017-08-04 2017-09-02  1703679  1746090.14 -42411.14     -2.49
# 4      4 2017-09-03 2017-10-02  1808586  1758607.64  49978.36      2.76
# 3      3 2017-10-03 2017-11-01  1570505  1509948.36  60556.64      3.86
# 2      2 2017-11-02 2017-12-01  1697172  1757080.61 -59908.61     -3.53
# 1      1 2017-12-02 2017-12-31  1438054  1490170.79 -52116.79     -3.62
#
#     Total Error  Total Error(%)      RMSE     MAPE  sMAPE
# 12    131476.37            8.70   5906.55  1985.47   8.60
# 11    125249.44            8.04   8437.40    14.24   8.25
# 10     92973.95            5.42   3839.60     7.10   5.51
# 9     156950.64            9.81  10444.70    19.65   9.95
# 8     132914.70            8.21  10594.37    16.84   8.33
# 7     140446.52            8.17   9298.69    13.60   8.17
# 6     112059.55            6.59   5394.79    10.63   6.52
# 5     164982.28            9.68   9523.04    13.48   9.56
# 4     145649.07            8.05   7179.29    19.49   8.17
# 3     178586.34           11.37  10182.55   122.64  11.59
# 2     109695.63            6.46   4677.23    19.39   6.35
# 1     107925.40            7.50   5064.74    18.68   7.37

# %%
a=131476 +125249+92973 + 156950 + 132914+ 140446+112059+164982+ 145649 +178586+109695+107925

# %%
a/360
# Out:
# 4441.4
